# %%
# %load_ext autoreload
# to make modification in .py file type %autoreload

# %load_ext line_profiler
#for finding out how long code takes to run
#an example of how to get diagnostics on functions
#%lprun -f ff.generate_map_full ff.generate_map_full(384, A_BB, alpha_BB, beta_sigma, freqs, nu0)

# %%
#trying to consolidate the work so far into a cohesive document and notation. Pushing definitions into 
#separate .py file

#------packages-------------------
# %pylab inline
import time
import healpy as hp
import matplotlib.pyplot as plt
import foreground_functions as ff
from scipy.optimize import curve_fit, minimize
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # parameters for generating map

# %%
nside = 128
A = 1.7e3
alpha = -3.0
beta = -3.2
gamma = -2.5
ells = np.arange(3*nside)
freqs = np.linspace(30, 300, 5)*1.e9

# %% [markdown]
# # define the model with these parameters (for comparison)

# %%
input_model = ff.model(freqs, A, alpha, beta, gamma)
input_model.shape
# Out:
# (5, 384)

# %% [markdown]
# # define 2d and 1d data

# %%
#instead of generating one power spectrum each time, let's write a reference power spectrum by averaging a bunch
#together and load this in to avoid any realisation problems.
N=100
start=time.time()
realisation = np.zeros((N, len(ells), len(freqs)))
for i in range(N):
    #printing progress for long runs.
    if (i/N*100)%5==0:
        print(str(np.round(i/N*100)) + '%')

    maps = ff.map_full_power(freqs)
    for j in range(len(freqs)):
        realisation[i,:,j] = hp.anafast(maps[j])
print('100%')

mean = np.mean(realisation, 0)
print(time.time()-start)
save('reference_PS', mean)
# Out:
# 0.0%
# 5.0%
# 10.0%
# 15.0%
# 20.0%
# 25.0%
# 30.0%
# 35.0%
# 40.0%
# 45.0%
# 50.0%
# 60.0%
# 65.0%
# 70.0%
# 75.0%
# 80.0%
# 85.0%
# 90.0%
# 95.0%
# 100%
# 118.97526907920837

# %%
mean = np.load('reference_PS.npy').T
mean.shape
semilogy(mean[0])

# %%
PS_data = mean
# PS_data = ff.PS_data(freqs, A, alpha, beta, gamma)

# %%
PS_data_1d = PS_data[0]
#1d data at 30 GHz.

# %%
#try residual stuff with this new 'full_model' function
def residuals(params, ells, freqs, data):
    chi2 = 0
    amp, alpha, beta, gamma = params
    model = ff.full_model(ells, freqs, amp, alpha, beta, gamma)

    #set up array of 2/(2*ell+1) then multiply by C_ell^2
    var = np.zeros((len(freqs),len(ells)))
    for ell in range(len(ells)):
        var[:,ell] = 2/(2*ell+1)
    cosmic_var = var * model**2
    chi2 = (data[2:] - model[2:])**2 / cosmic_var[2:]
#     print(chi2)
    return np.sum(chi2)

# %% [markdown]
# # Fit 0: test if minimize is moving

# %%
start=time.time()
result = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data), bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 208.27679896354675

# %%
result
# Out:
#       fun: 2811.7576517924444
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.04347385,  0.00645741, -0.00159162,  0.00463842])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 150
#       nit: 15
#    status: 0
#   success: True
#         x: array([999.9979063 ,  -4.24334977,  -3.85019602,  -2.76123515])

# %%
x = result.x

# %%
fitted_model = ff.model(freqs, x[0], x[1], x[2], x[3])
fitted_model.shape
# Out:
# (5, 384)

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fitted_model[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#okay, so it's kind of worked, though not super well. But it's running and moving.
#Test if the system is consistent now, with same input vector should get same output

# %% [markdown]
# # Fit 1: see if system is deterministic

# %%
start=time.time()
result_1 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data), bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 199.27151012420654

# %%
result_1
# Out:
#       fun: 2811.7576517924444
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.04347385,  0.00645741, -0.00159162,  0.00463842])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 150
#       nit: 15
#    status: 0
#   success: True
#         x: array([999.9979063 ,  -4.24334977,  -3.85019602,  -2.76123515])

# %%
x1 = result_1.x

# %%
x-x1
# Out:
# array([0., 0., 0., 0.])

# %%
#good, so model is deterministic as it should be now. Now can test different initial points and/or constraints/methods

# %% [markdown]
# # Fit 2: start closer to correct amplitude

# %%
start=time.time()
result_2 = minimize(residuals, [1.5e3, -1, -1, -3], args=(ells, freqs, PS_data), bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 226.13190293312073

# %%
x2 = result_2.x
print(x2)
# Out:
# [1499.99665476   -3.00194856   -3.04267332   -2.52866634]

# %%
fit2= ff.model(freqs, x2[0], x2[1], x2[2], x2[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fit2[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %% [markdown]
# # Fit 3: start at correct amplitude and see what others are found as

# %%
start=time.time()
result_3 = minimize(residuals, [A, -1, -1, -3], args=(ells, freqs, PS_data), bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 207.46563911437988

# %%
x3 = result_3.x
print(x3)
# Out:
# [1699.99818759   -3.06980754   -3.14449518   -2.48882821]

# %%
fit3= ff.model(freqs, x3[0], x3[1], x3[2], x3[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fit3[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#interesting. So it seems like the minimize program doesn't want to move away from the input amplitude, but
#can find pretty good values for the other parameters

# %% [markdown]
# # Fit 4: try this on a set of data generated from different inputs

# %%
A1 = 1.4e3
alpha1 = -3.5
beta1 = -2.8
gamma1 = -3.0

# %%
PS_data1 = ff.PS_data(freqs, A1, alpha1, beta1, gamma1)

# %%
input_model1 = ff.model(freqs, A1, alpha1, beta1, gamma1)

# %%
start=time.time()
result4 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data1), bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 420.78942012786865

# %%
x4 = result4.x
print(x4)
# Out:
# [1000.03512075   -3.41913081   -2.443418     -5.80968345]

# %%
print(A1, alpha1, beta1, gamma1)
# Out:
# 1400.0 -3.5 -2.8 -3.0

# %%
fit4= ff.model(freqs, x4[0], x4[1], x4[2], x4[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data1[i], label='data')
    semilogy(input_model1[i], label='input model')
    semilogy(fit4[i], label='fit model')
#     semilogy(ff.model(freqs, x5[0], -3.5, x5[2], x5[3])[i], label='fit corrected')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#so again the amplitude doesn't want to move...

# %% [markdown]
# # Fit 5: correct amplitude on these secondary data

# %%
start=time.time()
result5 = minimize(residuals, [A1, -1, -1, -3], args=(ells, freqs, PS_data1), bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 225.976815700531

# %%
x5 = result5.x
print(x5)
# Out:
# [1399.99942946   -3.54262018   -2.79901373   -3.05761602]

# %%
print(A1, alpha1, beta1, gamma1)
# Out:
# 1400.0 -3.5 -2.8 -3.0

# %%
fit5= ff.model(freqs, x5[0], x5[1], x5[2], x5[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data1[i], label='data')
    semilogy(input_model1[i], label='input model')
    semilogy(fit5[i], label='fit model')
#     semilogy(ff.model(freqs, x5[0], -3.5, x5[2], x5[3])[i], label='fit corrected')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#okay, so does well at different input parameters too, that's good
#however, this means that it's unlikely that the reason the minimizer isn't moving in A is due to a local
#minimum, maybe due to degeneracy?

# %% [markdown]
# # Fits 6-8: Try a different methods of minimization
# (go back to original data)
#
# Have to use methods compatible with bounds. These are:
# - L-BFGS-B
# - TNC
# - SLSQP
#
# The results we're trying to obtain are $[A, \alpha, \beta, \gamma] = [1700, -3.0, -3.2, -2.5]$

# %%
#L-BFGS-B

# %%
start=time.time()
result6 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data),
                   method='L-BFGS-B',bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 611.963142156601

# %%
result6
# Out:
#       fun: 291.3971056253306
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.70530257e-05, -2.58523869e-02,  2.44995135e-02,  6.82121026e-05])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 425
#       nit: 60
#    status: 0
#   success: True
#         x: array([1208.59175884,   -2.91062269,   -2.85262063,   -4.38274696])

# %%
x6_1 = result6.x
fit6_1 = ff.model(freqs, x6_1[0],x6_1[1],x6_1[2],x6_1[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fit6_1[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
best_fit = np.zeros(4)
best_fit[0] = 1654.73966519
best_fit[1] = -3.00910182
best_fit[2] = -3.19863922
best_fit[3] = -2.5963412

# %%
best_model = ff.model(freqs, best_fit[0], best_fit[1], best_fit[2], best_fit[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(best_model[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#previous attempt that worked well values

# %%
x6 = result6.x
print(x6)
# Out:
# [1654.73966519   -3.00910182   -3.19863922   -2.5963412 ]

# %%
print(A, alpha, beta, gamma)
# Out:
# 1700.0 -3.0 -3.2 -2.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-664023bee960> in <module>
#       1 print(A, alpha, beta, gamma)
# ----> 2 print(x6)
#
# NameError: name 'x6' is not defined

# %% [markdown]
# # !!!! Took a while but did move all the parameters. Let's see how they look

# %%
fit6= ff.model(freqs, x6[0], x6[1], x6[2], x6[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fit6[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#let's have a look at the other methods to see if they work and maybe run faster, if not we can live with this

# %%
#TNC

# %%
start=time.time()
result7 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data), 
                   method='TNC',bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# 825.7803790569305

# %%
x7=result7.x
print(x7)
# Out:
# [1151.95369989   -2.90535694   -2.92619152   -3.43125455]

# %%
fit7= ff.model(freqs, x7[0], x7[1], x7[2], x7[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fit7[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)

# %%
#interesting, so TNC doesn't work as well... Still moves all the parameters though

# %%
#SLSQP

# %%
start=time.time()
result8 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data), 
                   method='SLSQP',bounds=((None, None), (None, None), (None, None), (None, -2.01)))
print(time.time()-start)
# Out:
# /Users/alex/Documents/foreground_moments/foreground_functions.py:46: RuntimeWarning: overflow encountered in power
#   model[2:] = (ells[2:] / 80.)**alpha
# /Users/alex/Documents/foreground_moments/foreground_functions.py:62: RuntimeWarning: overflow encountered in power
#   return (nu/nu0)**(2.+beta[..., np.newaxis])
# /Users/alex/Documents/foreground_moments/foreground_functions.py:119: RuntimeWarning: invalid value encountered in multiply
#   bcls = bcls * (sigma/std)**2 #scaling the map scales the C_ell by the square factor
# /Users/alex/Documents/foreground_moments/foreground_functions.py:343: RuntimeWarning: invalid value encountered in multiply
#   moment0x0[i] = pcls * sed_scaling[i]**2
# /Users/alex/Documents/foreground_moments/foreground_functions.py:232: RuntimeWarning: invalid value encountered in double_scalars
#   wignersum += factor[ell1, ell2] * amp_cls[ell1] * beta_cls[ell2] * (w3j[:,ell1,ell2])
# /Users/alex/Documents/foreground_moments/foreground_functions.py:368: RuntimeWarning: invalid value encountered in double_scalars
#   sum *= A_beta / (4 * pi * 80**gamma)
# /Users/alex/Documents/foreground_moments/foreground_functions.py:370: RuntimeWarning: invalid value encountered in multiply
#   moment0x2[i] = np.log(freqs[i]/nu0_default)**2 * sed_scaling[i]**2 * pcls * sum
# /Users/alex/Documents/foreground_moments/foreground_functions.py:343: RuntimeWarning: overflow encountered in double_scalars
#   moment0x0[i] = pcls * sed_scaling[i]**2
# /Users/alex/Documents/foreground_moments/foreground_functions.py:354: RuntimeWarning: overflow encountered in double_scalars
#   moment1x1[i] =  np.log(freqs[i]/nu0_default)**2 * sed_scaling[i]**2 * wignersum
# /Users/alex/Documents/foreground_moments/foreground_functions.py:370: RuntimeWarning: overflow encountered in double_scalars
#   moment0x2[i] = np.log(freqs[i]/nu0_default)**2 * sed_scaling[i]**2 * pcls * sum
# /Users/alex/Documents/foreground_moments/foreground_functions.py:343: RuntimeWarning: overflow encountered in multiply
#   moment0x0[i] = pcls * sed_scaling[i]**2
# /Users/alex/Documents/foreground_moments/foreground_functions.py:232: RuntimeWarning: invalid value encountered in multiply
#   wignersum += factor[ell1, ell2] * amp_cls[ell1] * beta_cls[ell2] * (w3j[:,ell1,ell2])
# /Users/alex/Documents/foreground_moments/foreground_functions.py:370: RuntimeWarning: overflow encountered in multiply
#   moment0x2[i] = np.log(freqs[i]/nu0_default)**2 * sed_scaling[i]**2 * pcls * sum
# /Users/alex/Documents/foreground_moments/foreground_functions.py:47: RuntimeWarning: overflow encountered in multiply
#   return amp * model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-219b878702ea> in <module>
#       1 start=time.time()
#       2 result8 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data),
# ----> 3                    method='SLSQP',bounds=((None, None), (None, None), (None, None), (None, -2.01)))
#       4 print(time.time()-start)
#
# /anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     607     elif meth == 'slsqp':
#     608         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 609                                constraints, callback=callback, **options)
#     610     elif meth == 'trust-constr':
#     611         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# /anaconda3/lib/python3.7/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     397
#     398             # Compute objective function
# --> 399             fx = func(x)
#     400             try:
#     401                 fx = float(np.asarray(fx))
#
# /anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# <ipython-input-7-3d74d55f7677> in residuals(params, ells, freqs, data)
#       3     chi2 = 0
#       4     amp, alpha, beta, gamma = params
# ----> 5     model = ff.full_model(ells, freqs, amp, alpha, beta, gamma)
#       6
#       7     #set up array of 2/(2*ell+1) then multiply by C_ell^2
#
# ~/Documents/foreground_moments/foreground_functions.py in full_model(ells, freqs, A, alpha, beta, gamma)
#     333     pcls =powerlaw(ells, A, alpha)
#     334     sed_scaling = scale_synch(freqs, beta)
# --> 335     bcls, beta_map = map_power_beta(ell_max=ell_max, beta=beta, gamma=gamma)
#     336     #allows for single frequencies to be entered
#     337     if type(freqs)==np.float64 or type(freqs)==int or type(freqs)==float:
#
# ~/Documents/foreground_moments/foreground_functions.py in map_power_beta(ell_max, sigma, gamma, beta, nside)
#     100     ells = np.arange(0,ell_max)
#     101     bcls = powerlaw(ells, 1, gamma)
# --> 102     beta_map = hp.synfast(bcls, nside, new=True, verbose=False)
#     103
#     104     #model the standard deviation as a function of gamma
#
# /anaconda3/lib/python3.7/site-packages/healpy/sphtfunc.py in synfast(cls, nside, lmax, mmax, alm, pol, pixwin, fwhm, sigma, new, verbose)
#     539         sigma=sigma,
#     540         inplace=True,
# --> 541         verbose=verbose,
#     542     )
#     543     if alm:
#
# /anaconda3/lib/python3.7/site-packages/healpy/sphtfunc.py in alm2map(alms, nside, lmax, mmax, pixwin, fwhm, sigma, pol, inplace, verbose)
#     337     if pol:
#     338         output = sphtlib._alm2map(
# --> 339             alms_new[0] if lonely else tuple(alms_new), nside, lmax=lmax, mmax=mmax
#     340         )
#     341         if lonely:
#
# KeyboardInterrupt:

# %%
#interesting, this one gets angry...

# %% [markdown]
# # Fit 9: Try tighter bounds on each component, rather than just bounding $\gamma$

# %%
start=time.time()
result9 = minimize(residuals, [1e3, -1, -1, -3], args=(ells, freqs, PS_data),
                   method='L-BFGS-B',bounds=((.9e3, 3e3), (-6, 0), (-6, 0), (-4, -2.01)))
print(time.time()-start)
# Out:
# 464.77010703086853

# %%
x9 = result9.x
print(x9)
# Out:
# [1357.63248776   -2.93641553   -2.98943541   -4.        ]

# %%
#interesting, ran faster but tighter constraints actually made the estimates worse...

# %%
fit9= ff.model(freqs, x9[0], x9[1], x9[2], x9[3])

# %%
for i in range(len(freqs)):
    figure(figsize=(13,7))
    semilogy(PS_data[i], label='data')
    semilogy(input_model[i], label='input model')
    semilogy(fit9[i], label='fit model')
    title('Fits from minimization at {:.2f} GHz'.format(freqs[i]/1e9))
    legend()
    xlim(2,400)
