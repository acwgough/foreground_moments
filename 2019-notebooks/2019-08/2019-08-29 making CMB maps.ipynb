# %%
# %load_ext autoreload
# to make modification in .py file type %autoreload

# %load_ext line_profiler
#for finding out how long code takes to run
#an example of how to get diagnostics on functions
#%lprun -f ff.generate_map_full ff.generate_map_full(384, A_BB, alpha_BB, beta_sigma, freqs, nu0)

# %%
import sys
sys.path.append('../../') #takes us to the directory named foreground_functions that housed the foreground_function.py 
#and the w3j.npy files


#------packages-------------------
# %pylab inline
import time
import healpy as hp
import matplotlib.pyplot as plt
import foreground_functions as ff
from scipy.optimize import curve_fit, minimize
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
camb_lens_r1 = loadtxt('../../camb_lens_r1.dat').T

# %%
camb_lens_nobb = loadtxt('../../camb_lens_nobb.dat').T

# %%
ells = camb_lens_r1[0]

# %%
primo_bb = camb_lens_r1[3]

# %%
lens_bb = camb_lens_nobb[3]

# %%
ells.shape
# Out:
# (1950,)

# %%
semilogy(ells, camb_lens_r1[1])
semilogy(ells, camb_lens_r1[2])
semilogy(ells, camb_lens_r1[3])

# %%
semilogy(ells, camb_lens_nobb[1])
semilogy(ells, camb_lens_nobb[2])
semilogy(ells, camb_lens_nobb[3])

# %%
r = 0.01

# %%
bb = r * primo_bb + lens_bb

# %%
loglog(ells, bb)
loglog(ells, r*primo_bb)
loglog(ells, lens_bb)
xlim(30,1000)
ylim(1e-4,1e-1)
# Out:
# (0.0001, 0.1)
